# %%
import tensorflow as tf

if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %% [markdown]
# # MNIST
#
# * Entropia Global das Imagens (Entropia Aplicada Diretamente flatten)

# %% [markdown]
# # Apartir daqui aplicamos entropia no filtro de validação também (o v09) não executa essa ação.

# %% [markdown]
# ## Criação e definição de todas as funções
#
# 1.   Filtro de Entropia
# 2.   Carregamento, Preprocesssamento e Tratamento
# 3.   Criação do Modelo
# 4.   Predições Estatisticas
# 5.   Plot de Acuracy e Loss

# %%
from keras.datasets import mnist
import numpy as np
from scipy.stats import entropy
import matplotlib.pyplot as plt
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.models import Sequential
from keras.optimizers import SGD
from sklearn import metrics
from sklearn.metrics import accuracy_score, recall_score
from keras.utils import to_categorical
from keras.layers import Dropout
from keras.layers import BatchNormalization
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import time

def filtrar_entropia_median(train_X, train_y):  # filtro de entropia
    base = 2 # base de logaritimo
    tuplasEntropia = [(index, entropy(img.flatten(), base = base)) for index, img in enumerate(train_X)] #operacao de flaten sob base para calcular entropia e enumerar
    entropiesLocal_ordenado = sorted(tuplasEntropia, key=lambda x: x[1]) #ordenação com base na entropia
    n = len(entropiesLocal_ordenado)
    if n % 2 == 1:
        median = entropiesLocal_ordenado[n // 2][1] # mediana elemento do meio - impares
    else:
        median = (entropiesLocal_ordenado[n // 2 - 1][1] + entropiesLocal_ordenado[n // 2][1]) / 2.0  # mediana elemento do meio-pares
    indices_filtrados = [item[0] for item in entropiesLocal_ordenado if item[1] <= median]  #selecionando os indices de entropia entropia baixa abaixo da mediana.
    train_X = np.array([train_X[i] for i in indices_filtrados]) # passa os indices selecionados para base de treino
    train_y = np.array([train_y[i] for i in indices_filtrados]) # passa os indices selecionados para base de labels
    return train_X, train_y

def filtrar_entropia_median_train_teste(train_X, train_y, test_X, test_y):  # filtro de entropia
    base = 2 # base de logaritimo
    tuplasEntropia = [(index, entropy(img.flatten(), base = base)) for index, img in enumerate(train_X)] #operacao de flaten sob base para calcular entropia e enumerar
    tuplasEntropiaTeste = [(index, entropy(img.flatten(), base = base)) for index, img in enumerate(test_X)] #operacao de flaten sob base para calcular entropia e enumerar
    entropiesLocal_ordenado = sorted(tuplasEntropia, key=lambda x: x[1]) #ordenação com base na entropia
    entropiesLocal_ordenadoTeste = sorted(tuplasEntropiaTeste, key=lambda x: x[1]) #ordenação com base na entropia
    n = len(entropiesLocal_ordenado)
    if n % 2 == 1:
        median = entropiesLocal_ordenado[n // 2][1] # mediana elemento do meio - impares
    else:
        median = (entropiesLocal_ordenado[n // 2 - 1][1] + entropiesLocal_ordenado[n // 2][1]) / 2.0  # mediana elemento do meio-pares
    indices_filtrados = [item[0] for item in entropiesLocal_ordenado if item[1] <= median]  #selecionando os indices de entropia entropia baixa abaixo da mediana.
    indices_filtradosTeste = [item[0] for item in entropiesLocal_ordenadoTeste if item[1] <= median]  #selecionando os indices de entropia entropia baixa abaixo da mediana.
    train_X = np.array([train_X[i] for i in indices_filtrados]) # passa os indices selecionados para base de treino
    train_y = np.array([train_y[i] for i in indices_filtrados]) # passa os indices selecionados para base de labels
    test_X = np.array([test_X[i] for i in indices_filtradosTeste]) # passa os indices selecionados para base de treino
    test_y = np.array([test_y[i] for i in indices_filtradosTeste]) # passa os indices selecionados para base de labels    
    return train_X, train_y, test_X, test_y

def carregarPeparar(train_X, train_y, test_X, test_y, d, c): # Carregamento e Tratamento
  train_X = train_X.reshape((train_X.shape[0], d, d, c))   # Ajuste da dimensão
  test_X = test_X.reshape((test_X.shape[0], d, d, c))    # Ajuste da dimensão
  train_X = train_X.astype("float")/255.0     # Normalização
  test_X = test_X.astype("float")/255.0     # Normalização
  train_y = to_categorical(train_y, 10) #10 classes possiveis   -   # to Categorical para as classes
  test_y = to_categorical(test_y, 10) #10 classes possiveis     -   # to Categorical para as classes
  return train_X, train_y, test_X, test_y

def avaliacao_statistica(test_X, test_y):
    predictions = model.predict(test_X) # Previsões
    classePredita = np.argmax(predictions, axis=1)
    classeVerdadeira = np.argmax(test_y, axis=1)
    cm = confusion_matrix(classeVerdadeira, classePredita)
    ConfusionMatrixDisplay(cm).plot()  # classePredita para matrix de confusao
    acc = accuracy_score(classeVerdadeira, classePredita) * 100  # Acuracia
    print("Acuracia: ", '%.3f' % (acc*1.0))
    sens = recall_score(classeVerdadeira, classePredita, average='macro')  # Sensibilidade
    print("Sensibilidade: ", '%.3f' % (sens*1.0))

def plotAcuraciaLoss(history): #plots
  plt.figure(figsize=(12, 5))
  plt.subplot(1, 2, 1)  # 1 linha, 2 colunas, primeiro gráfico  # Primeiro gráfico (accuracy)
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('Model Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Validation'], loc='upper left')
  plt.subplot(1, 2, 2)  # 1 linha, 2 colunas, segundo gráfico # Segundo gráfico (loss)
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Model Loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Validation'], loc='upper left')
  plt.tight_layout() # Exibir os gráficos

def plotarDadosTrain(index_inicio, qtd, train_X): # Exemplo: apartir do indice N, exibe K imagens do conjunto de dados, D
  base = 330
  import matplotlib.pyplot as plt
  for i in range(index_inicio, index_inicio + qtd):
      plt.subplot(base + 1 + (i - index_inicio))
      plt.imshow(train_X[i], cmap=plt.get_cmap('gray'))
  plt.show()
  print(train_y[index_inicio:index_inicio + qtd])

def tempDecorrido(inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF, entropiaF = None): # x = time.time() || inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF, entropiaF
  elapsed_time = [["Carregar DataSet", 0], ["Filtro Entropia", 0], ["Pre-processamento", 0], ["Criação do Modelo", 0], ["Treinamento", 0], ["Inicio à Fim Execução" , 0]]
  elapsed_time[0][1] = importacaoF - inicio  # tempo de inicio de execução até o final da importação do dataset
  if (entropiaF != None): elapsed_time[1][1] = entropiaF - importacaoF  # Tempo gasto Inicio é importaçãoF - Execução da Entropia
  elapsed_time[2][1] = padrozinacaoF - importacaoF  # pega o tempo da entropia e subtrai do tempo apos a padronização para verificar quanto tempo padronizacao demorou
  elapsed_time[3][1] = criacaoModeloF - padrozinacaoF  # tempo da padronizacao - tempo apos a criacao do modelo para verificar tempo decorido
  elapsed_time[4][1] = treinamentoF - criacaoModeloF  # tempo inicial é marcado pela criacaoModeloF - tempoTreinamento que marca o momento que treinamento terminou
  elapsed_time[5][1] = treinamentoF - inicio #tempo total de execução inicio| importações até final da Execução | treinamento
  for index, tempo in enumerate(elapsed_time):
    if entropiaF is None and index == 1:
      continue
    print("{}: {:.4f}".format(tempo[0], round(tempo[1], 2)) + str(" em milissegundos"))

# %% [markdown]
# ### [MNIST]Treinamento e ordem de execução das funções
#   * **[Modelo da CNN para MNIST]**

# %%
def criacaoModeloF1(): # Criação do Modelo
  model = Sequential()
  model.add(Conv2D(32, (3,3), activation = 'relu', kernel_initializer = 'he_uniform', input_shape = (28, 28, 1)))
  model.add(MaxPooling2D((2, 2)))

  model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(Dropout(0.4))
  model.add(BatchNormalization())
  model.add(MaxPooling2D((2, 2)))

  model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D((2, 2)))

  model.add(Flatten())
  model.add(Dense(128, activation = 'relu', kernel_initializer = 'he_uniform'))
  model.add(Dropout(0.5))
  model.add(Dense(10, activation = 'softmax'))  # classificação 10 categorias

  opt = SGD(learning_rate=0.01, momentum =0.9) #copilaçãoModelo
  model.compile(optimizer=opt, loss = 'categorical_crossentropy', metrics= ['accuracy'])
  return model

# %% [markdown]
# ### [MNIST]Treinamento e ordem de execução das funções
#   * **[Sem seleção de entropia]**
#   * **[Dataset Completo]**

# %%
inicio = time.time() #tempo de inicio
(train_X, train_y), (test_X, test_y) = mnist.load_data() # Carregar o conjunto de dados # Importar e Treinar
importacaoF = time.time() #tempo de importacao
train_X, train_y, test_X, test_y = carregarPeparar(train_X, train_y, test_X, test_y, 28, 1) #padronização e categorização
padrozinacaoF = time.time() #tempo de padronizacao
model = criacaoModeloF1() # instanciando o modelo
criacaoModeloF = time.time() #tempo de criacao do modelo
history = model.fit(train_X, train_y, epochs = 10, batch_size = 32, validation_data=(test_X, test_y), verbose = 1) #treinamento
treinamentoF = time.time() #tempo final

tempDecorrido(inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF) #inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF, entropiaF
#plotarDadosTrain(3000, 9, train_X) # Exemplo: apartir do indice N, exibe K imagens do conjunto de dados, D
avaliacao_statistica(test_X, test_y)
plotAcuraciaLoss(history)

# %% [markdown]
# ### [MNIST]Treinamento e ordem de execução das funções
#   * **[Sem seleção de entropia]**
#   * **[Dataset Divido na metade e aletatorio]**

# %%
from sklearn.model_selection import train_test_split
import random
def selecionar_metade_aleatoria(metade1, metade2):
    return metade1 if random.choice([True, False]) else metade2

inicio = time.time() #tempo de inicio
(train_X, train_y), (test_X, test_y) = mnist.load_data() # Carregar o conjunto de dados # Importar e Treinar
metade_train_X, outra_metade_train_X, metade_train_y, outra_metade_train_y = train_test_split(train_X, train_y, test_size=0.5, random_state=42) # Corte aleatorio do dataset na metade
train_X = selecionar_metade_aleatoria(metade_train_X, outra_metade_train_X)
train_y = selecionar_metade_aleatoria(metade_train_y, outra_metade_train_y)

importacaoF = time.time() #tempo de importacao
train_X, train_y, test_X, test_y = carregarPeparar(train_X, train_y, test_X, test_y, 28, 1) #padronização e categorização
padrozinacaoF = time.time() #tempo de padronizacao
model = criacaoModeloF1() # instanciando o modelo
criacaoModeloF = time.time() #tempo de criacao do modelo
history = model.fit(train_X, train_y, epochs = 10, batch_size = 32, validation_data=(test_X, test_y), verbose = 1) #treinamento
treinamentoF = time.time() #tempo final

tempDecorrido(inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF) #inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF, entropiaF
#plotarDadosTrain(3000, 9, train_X) # Exemplo: apartir do indice N, exibe K imagens do conjunto de dados, D
avaliacao_statistica(test_X, test_y)
plotAcuraciaLoss(history)

# %% [markdown]
# ## [MNIST]Treinamento e ordem de execução das funções
#  * **[Modelo selecionado com entropia]**
#  * **Baixa Entropia**

# %% [markdown]
# ### Filtro de entropia :
#   * Dataset filtrado
#   * Baixa Entropia

# %%
inicio = time.time() #tempo de inicio
(train_X, train_y), (test_X, test_y) = mnist.load_data() # Carregar o conjunto de dados # Importar e Treinar
importacaoF = time.time() #tempo de importacao
train_X, train_y = filtrar_entropia_median(train_X, train_y)  #filtro de entropia sob conjunto de dados de treino
entropiaF = time.time() #tempo de filtragem entropia
train_X, train_y, test_X, test_y = carregarPeparar(train_X, train_y, test_X, test_y, 28, 1) #padronização e categorização
padrozinacaoF = time.time() #tempo de padronizacao
model = criacaoModeloF1() # instanciando o modelo
criacaoModeloF = time.time() #tempo de criacao do modelo
history = model.fit(train_X, train_y, epochs = 10, batch_size = 32, validation_data=(test_X, test_y), verbose = 1) #treinamento
treinamentoF = time.time() #tempo final

tempDecorrido(inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF, entropiaF) #inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF, entropiaF
#plotarDadosTrain(3000, 9, train_X) # Exemplo: apartir do indice N, exibe K imagens do conjunto de dados, D
avaliacao_statistica(test_X, test_y)
plotAcuraciaLoss(history)

# %% [markdown]
# ### Filtro de entropia :
#   * Dataset filtrado
#   * Median transferida para conjunto de treino e teste

# %%
inicio = time.time() #tempo de inicio
(train_X, train_y), (test_X, test_y) = mnist.load_data() # Carregar o conjunto de dados # Importar e Treinar
importacaoF = time.time() #tempo de importacao
train_X, train_y, test_X, test_y = filtrar_entropia_median_train_teste(train_X, train_y, test_X, test_y) #novo filtro da reunião 03-10-2023
entropiaF = time.time() #tempo de filtragem entropia
train_X, train_y, test_X, test_y = carregarPeparar(train_X, train_y, test_X, test_y, 28, 1) #padronização e categorização
padrozinacaoF = time.time() #tempo de padronizacao
model = criacaoModeloF1() # instanciando o modelo
criacaoModeloF = time.time() #tempo de criacao do modelo
history = model.fit(train_X, train_y, epochs = 10, batch_size = 32, validation_data=(test_X, test_y), verbose = 1) #treinamento
treinamentoF = time.time() #tempo final

tempDecorrido(inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF, entropiaF) #inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF, entropiaF
#plotarDadosTrain(3000, 9, train_X) # Exemplo: apartir do indice N, exibe K imagens do conjunto de dados, D
avaliacao_statistica(test_X, test_y)
plotAcuraciaLoss(history)

# %% [markdown]
# ### Filtro de entropia :
#   * Dataset filtrado
#   * Median transferida para conjunto de treino
#   * Cross-validation

# %%
from sklearn.model_selection import KFold

def crossValidation(combinado_treino_X, combinado_validacao_y,n_folds = 5):
    #divide seus dados em k folds, e treina no k−1 e valida em 1 fold, então a proporção de dados usados para validação é 1/k.
    #2 folds (50% de validação): Treina em 50% dos dados e valida nos outros 50%.
    #5 folds (20% de validação): Treina em 80% dos dados e valida em 20%.
    #10 folds (10% de validação): Treina em 90% dos dados e valida em 10%.    
    n_fold = 5 if n_folds == 0 else n_folds
    
    kf = KFold(n_splits = n_folds, shuffle = True, random_state = 42)  #divisão do conjunto de dados
    fold_no = 1
    for train, test in kf.split(combinado_treino_X, combinado_validacao_y):
        print(f"Treinando a rede no folder numero: {fold_no}")
        model = criacaoModeloF1() # instanciando o modelo
        inicio = time.time() #tempo de inicio
        history = model.fit(combinado_treino_X[train], combinado_validacao_y[train], epochs = 10, batch_size = 32, verbose = 1, validation_data = (combinado_treino_X[test], combinado_validacao_y[test]))
        treinamentoF = time.time() #tempo final
        tempoTreino = round(treinamentoF - inicio,2)
        scores = model.evaluate(combinado_treino_X[test], combinado_validacao_y[test], verbose = 1)
        print(f"Num do Folder: {fold_no}: Taxa de Loss: {scores[0]}, Taxa de Acuracia: {scores[1]*100:.2f}%, Tamanho do Conjunto de Dados: {len(combinado_treino_X[train])}, Tempo de Treino: {tempoTreino}")
        plt.figure(figsize=(12, 5))
        plt.subplot(1, 2, 1)  # 1 linha, 2 colunas, primeiro gráfico  # Primeiro gráfico (accuracy)
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy']) # Métrica de validação
        plt.title(f'Model Accuracy: {fold_no}')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.subplot(1, 2, 2)  # 1 linha, 2 colunas, segundo gráfico # Segundo gráfico (loss)
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss']) # Métrica de validação
        plt.title(f'Model Loss: {fold_no}')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.tight_layout() # Exibir os gráficos       
        fold_no += 1
        print("\n")
        
#carregar os dados    
(train_X, train_y), (test_X, test_y) = mnist.load_data() # Carregar o conjunto de dados # Importar e Treinar
train_X, train_y, test_X, test_y = filtrar_entropia_median_train_teste(train_X, train_y, test_X, test_y) #novo filtro da reunião 03-10-2023
train_X, train_y, test_X, test_y = carregarPeparar(train_X, train_y, test_X, test_y, 28, 1) #padronização e categorização
combinado_treino_X = np.concatenate([train_X, test_X], axis=0)
combinado_validacao_y = np.concatenate([train_y, test_y], axis=0)

#criar/instanciar o modelo para validação cruzada
crossValidation(combinado_treino_X,combinado_validacao_y, 10)

# %% [markdown]
# # Importando Dados CIFAR-10
#
# * Entropia Global das Imagens (Entropia Aplicada Diretamente flatten)

# %% [markdown]
# ## Criação e definição de todas as funções
#
# 1.   Filtro de Entropia
# 2.   Carregamento, Preprocesssamento e Tratamento
# 3.   Criação do Modelo [mesmo modelo do MNIST]
# 4.   Predições Estatisticas
# 5.   Plot de Acuracy e Loss

# %% [markdown]
# ### [CIFAR]Treinamento e ordem de execução das funções
#  * **[Modelo selecionado sem entropia]**

# %%
from keras import regularizers
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers.schedules import ExponentialDecay
def criacaoModeloG8(x_train):
    weight_decay = 1e-4
    model = Sequential()
    model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
    model.add(Activation('elu'))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('elu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('elu'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('elu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))

    model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('elu'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('elu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.4))

    model.add(Flatten())
    model.add(Dense(10, activation='softmax'))

    initial_learning_rate = 0.001
    lr_schedule = ExponentialDecay(
      initial_learning_rate,
      decay_steps=100000,
      decay_rate=0.96,
      staircase=True)

    opt = SGD(learning_rate=lr_schedule, momentum=0.9)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
from keras.datasets import cifar10
inicio = time.time() #tempo de inicio
(train_X, train_y), (test_X, test_y) = cifar10.load_data() # Carregar o conjunto de dados # Importar e Treinar

importacaoF = time.time() #tempo de importacao e datagen
train_X, train_y, test_X, test_y = carregarPeparar(train_X, train_y, test_X, test_y, 32, 3) #padronização e categorização
padrozinacaoF = time.time() #tempo de padronizacao
model = criacaoModeloG8(train_X) # instanciando o modelo
criacaoModeloF = time.time() #tempo de criacao do modelo
history = model.fit(train_X, train_y, epochs = 50, batch_size = 128, validation_data=(test_X, test_y), verbose = 1) #treinamento
treinamentoF = time.time() #tempo final

tempDecorrido(inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF) #inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF, entropiaF
#plotarDadosTrain(3000, 9, train_X) # Exemplo: apartir do indice N, exibe K imagens do conjunto de dados, D
avaliacao_statistica(test_X, test_y)
plotAcuraciaLoss(history)

# %% [markdown]
# ## ajuste para cifar10 com data gen <==================

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras.optimizers import Adam
def criacaoModeloG9():
    opt=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='elu', input_shape=(32, 32, 3), padding='same'))
    model.add(BatchNormalization(axis=-1))
    model.add(Conv2D(32, (3, 3), activation='elu', padding='same'))
    model.add(BatchNormalization(axis=-1))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(64, (3, 3), activation='elu', padding='same'))
    model.add(BatchNormalization(axis=-1))
    model.add(Conv2D(64, (3, 3), activation='elu', padding='same'))
    model.add(BatchNormalization(axis=-1))
    model.add(MaxPooling2D(pool_size=(2, 2)))   
    model.add(Dropout(0.3))

    model.add(Conv2D(128, (3, 3), activation='elu', padding='same'))
    model.add(BatchNormalization(axis=-1))
    model.add(Conv2D(128, (3, 3), activation='elu', padding='same'))
    model.add(BatchNormalization(axis=-1))
    model.add(MaxPooling2D(pool_size=(2, 2)))   
    model.add(Dropout(0.4))

    model.add(Flatten())
    model.add(Dense(512, activation='elu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer=opt)
    return model

# %% [markdown]
# ## Nova CNN para Cifar10 -modelo G9

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras.optimizers import Adam

def criacaoModeloG9():
    opt=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='elu', input_shape=(32, 32, 3), padding='same'))
    model.add(BatchNormalization(axis=-1))
    model.add(Conv2D(32, (3, 3), activation='elu', padding='same'))
    model.add(BatchNormalization(axis=-1))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(64, (3, 3), activation='elu', padding='same'))
    model.add(BatchNormalization(axis=-1))
    model.add(Conv2D(64, (3, 3), activation='elu', padding='same'))
    model.add(BatchNormalization(axis=-1))
    model.add(MaxPooling2D(pool_size=(2, 2)))   
    model.add(Dropout(0.3))

    model.add(Conv2D(128, (3, 3), activation='elu', padding='same'))
    model.add(BatchNormalization(axis=-1))
    model.add(Conv2D(128, (3, 3), activation='elu', padding='same'))
    model.add(BatchNormalization(axis=-1))
    model.add(MaxPooling2D(pool_size=(2, 2)))   
    model.add(Dropout(0.4))

    model.add(Flatten())
    model.add(Dense(512, activation='elu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer=opt)
    return model

from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator

(train_X, train_y), (test_X, test_y) = cifar10.load_data() # Carregar o conjunto de dados # Importar e Treinar
train_X, train_y, test_X, test_y = carregarPeparar(train_X, train_y, test_X, test_y, 32, 3) #padronização e categorização

datagen = ImageDataGenerator(rotation_range=15,horizontal_flip=True,width_shift_range=0.1,height_shift_range=0.1)
datagen.fit(train_X)
    
model = criacaoModeloG9()
inicio = time.time() #tempo de inicio
history=model.fit(datagen.flow(train_X, train_y, batch_size=128),
                    steps_per_epoch = len(train_X) / 128, epochs=50, validation_data=(test_X, test_y))
treinamentoF = time.time() #tempo final
tempoTreino = round(treinamentoF - inicio,2)
print("Tempo de treinamento: ", tempoTreino)
avaliacao_statistica(test_X, test_y)
plotAcuraciaLoss(history)
# Out:
# Epoch 1/50
# 390/390 [==============================] - 47s 112ms/step - loss: 1.8137 - accuracy: 0.4068 - val_loss: 1.6562 - val_accuracy: 0.4377
# Epoch 2/50
# 390/390 [==============================] - 50s 127ms/step - loss: 1.2495 - accuracy: 0.5564 - val_loss: 1.2051 - val_accuracy: 0.5963
# Epoch 3/50
# 390/390 [==============================] - 44s 113ms/step - loss: 1.0516 - accuracy: 0.6260 - val_loss: 0.9394 - val_accuracy: 0.6755
# Epoch 4/50
# 390/390 [==============================] - 54s 138ms/step - loss: 0.9533 - accuracy: 0.6655 - val_loss: 0.9134 - val_accuracy: 0.6922
# Epoch 5/50
# 390/390 [==============================] - 48s 122ms/step - loss: 0.8753 - accuracy: 0.6904 - val_loss: 0.7672 - val_accuracy: 0.7374
# Epoch 6/50
# 390/390 [==============================] - 51s 131ms/step - loss: 0.8185 - accuracy: 0.7123 - val_loss: 1.0758 - val_accuracy: 0.6438
# Epoch 7/50
# 390/390 [==============================] - 52s 133ms/step - loss: 0.7710 - accuracy: 0.7301 - val_loss: 0.6888 - val_accuracy: 0.7628
# Epoch 8/50
# 390/390 [==============================] - 56s 143ms/step - loss: 0.7349 - accuracy: 0.7424 - val_loss: 0.8655 - val_accuracy: 0.7158
# Epoch 9/50
# 390/390 [==============================] - 51s 130ms/step - loss: 0.6984 - accuracy: 0.7569 - val_loss: 0.6335 - val_accuracy: 0.7828
# Epoch 10/50
# 390/390 [==============================] - 51s 130ms/step - loss: 0.6750 - accuracy: 0.7656 - val_loss: 0.6582 - val_accuracy: 0.7783
# Epoch 11/50
# 390/390 [==============================] - 46s 117ms/step - loss: 0.6532 - accuracy: 0.7725 - val_loss: 0.6303 - val_accuracy: 0.7852
# Epoch 12/50
# 390/390 [==============================] - 49s 125ms/step - loss: 0.6317 - accuracy: 0.7805 - val_loss: 0.6237 - val_accuracy: 0.7879
# Epoch 13/50
# 390/390 [==============================] - 51s 132ms/step - loss: 0.6138 - accuracy: 0.7854 - val_loss: 0.6225 - val_accuracy: 0.7918
# 390/390 [==============================] - 84s 216ms/step - loss: 0.4366 - accuracy: 0.8473 - val_loss: 0.4274 - val_accuracy: 0.8522
# Epoch 34/50
# 390/390 [==============================] - 85s 217ms/step - loss: 0.4331 - accuracy: 0.8495 - val_loss: 0.4631 - val_accuracy: 0.8448
# Epoch 35/50
# 390/390 [==============================] - 85s 217ms/step - loss: 0.4289 - accuracy: 0.8525 - val_loss: 0.4359 - val_accuracy: 0.8494
# Epoch 36/50
# 390/390 [==============================] - 95s 242ms/step - loss: 0.4290 - accuracy: 0.8505 - val_loss: 0.4793 - val_accuracy: 0.8480
# Epoch 37/50
# 390/390 [==============================] - 139s 357ms/step - loss: 0.4203 - accuracy: 0.8537 - val_loss: 0.4518 - val_accuracy: 0.8488
# Epoch 38/50
# 390/390 [==============================] - 68s 174ms/step - loss: 0.4158 - accuracy: 0.8541 - val_loss: 0.4114 - val_accuracy: 0.8628
# Epoch 39/50
# 390/390 [==============================] - 60s 153ms/step - loss: 0.4161 - accuracy: 0.8544 - val_loss: 0.4371 - val_accuracy: 0.8518
# Epoch 40/50
# 390/390 [==============================] - 63s 160ms/step - loss: 0.4130 - accuracy: 0.8562 - val_loss: 0.4629 - val_accuracy: 0.8496
# Epoch 41/50
# 390/390 [==============================] - 68s 174ms/step - loss: 0.4083 - accuracy: 0.8568 - val_loss: 0.4354 - val_accuracy: 0.8597
# Epoch 42/50
# 390/390 [==============================] - 61s 156ms/step - loss: 0.4065 - accuracy: 0.8590 - val_loss: 0.3850 - val_accuracy: 0.8714
# Epoch 43/50
# 390/390 [==============================] - 51s 130ms/step - loss: 0.3971 - accuracy: 0.8615 - val_loss: 0.4294 - val_accuracy: 0.8606
# Epoch 44/50
# 390/390 [==============================] - 54s 137ms/step - loss: 0.4031 - accuracy: 0.8601 - val_loss: 0.4238 - val_accuracy: 0.8618
# Epoch 45/50
# 390/390 [==============================] - 52s 132ms/step - loss: 0.4041 - accuracy: 0.8615 - val_loss: 0.3943 - val_accuracy: 0.8667
# Epoch 46/50
# 390/390 [==============================] - 48s 123ms/step - loss: 0.3924 - accuracy: 0.8636 - val_loss: 0.4145 - val_accuracy: 0.8647
# Epoch 47/50
# 390/390 [==============================] - 48s 122ms/step - loss: 0.3907 - accuracy: 0.8654 - val_loss: 0.3985 - val_accuracy: 0.8680
# Epoch 48/50
# 390/390 [==============================] - 48s 122ms/step - loss: 0.3865 - accuracy: 0.8665 - val_loss: 0.4305 - val_accuracy: 0.8584
# Epoch 49/50
# 390/390 [==============================] - 48s 124ms/step - loss: 0.3858 - accuracy: 0.8641 - val_loss: 0.3783 - val_accuracy: 0.8762
# Epoch 50/50
# 390/390 [==============================] - 62s 158ms/step - loss: 0.3802 - accuracy: 0.8677 - val_loss: 0.3720 - val_accuracy: 0.8778
# Tempo de treinamento:  3332.09
# 313/313 [==============================] - 14s 8ms/step
# Acuracia:  87.780
# Sensibilidade:  0.878

# %% [markdown]
#   ### [CIFAR]Treinamento e ordem de execução das funções
#   * **[Sem seleção de entropia]**
#   * **[Dataset Divido na metade e aletatorio]**

# %%
from sklearn.model_selection import train_test_split
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
import random
def selecionar_metade_aleatoria(metade1, metade2):
    return metade1 if random.choice([True, False]) else metade2

inicio = time.time() #tempo de inicio
(train_X, train_y), (test_X, test_y) = cifar10.load_data() # Carregar o conjunto de dados # Importar e Treinar
metade_train_X, outra_metade_train_X, metade_train_y, outra_metade_train_y = train_test_split(train_X, train_y, test_size=0.5, random_state=42) # Corte aleatorio do dataset na metade
train_X = selecionar_metade_aleatoria(metade_train_X, outra_metade_train_X)
train_y = selecionar_metade_aleatoria(metade_train_y, outra_metade_train_y)

importacaoF = time.time() #tempo de importacao
train_X, train_y, test_X, test_y = carregarPeparar(train_X, train_y, test_X, test_y, 32, 3) #padronização e categorização
datagen = ImageDataGenerator(rotation_range=15,horizontal_flip=True,width_shift_range=0.1,height_shift_range=0.1)
datagen.fit(train_X)
padrozinacaoF = time.time() #tempo de padronizacao
model = criacaoModeloG9()
criacaoModeloF = time.time() #tempo de criacao do modelo
history=model.fit(datagen.flow(train_X, train_y, batch_size=128),
                    steps_per_epoch = len(train_X) / 128, epochs=50, validation_data=(test_X, test_y))
treinamentoF = time.time() #tempo final

tempDecorrido(inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF) #inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF, entropiaF
#plotarDadosTrain(3000, 9, train_X) # Exemplo: apartir do indice N, exibe K imagens do conjunto de dados, D
avaliacao_statistica(test_X, test_y)
plotAcuraciaLoss(history)
# Out:
# Epoch 1/50
# 195/195 [==============================] - 36s 126ms/step - loss: 2.9634 - accuracy: 0.1034 - val_loss: 2.3312 - val_accuracy: 0.1316
# Epoch 2/50
# 195/195 [==============================] - 24s 121ms/step - loss: 2.5606 - accuracy: 0.0996 - val_loss: 2.2766 - val_accuracy: 0.1360
# Epoch 3/50
# 195/195 [==============================] - 23s 118ms/step - loss: 2.4289 - accuracy: 0.1044 - val_loss: 2.3913 - val_accuracy: 0.0696
# Epoch 4/50
# 195/195 [==============================] - 24s 124ms/step - loss: 2.3878 - accuracy: 0.1011 - val_loss: 2.3069 - val_accuracy: 0.1017
# Epoch 5/50
# 195/195 [==============================] - 24s 121ms/step - loss: 2.3629 - accuracy: 0.0975 - val_loss: 2.2493 - val_accuracy: 0.1551
# Epoch 6/50
# 195/195 [==============================] - 23s 118ms/step - loss: 2.3466 - accuracy: 0.1000 - val_loss: 2.3329 - val_accuracy: 0.1033
# Epoch 7/50
# 195/195 [==============================] - 25s 126ms/step - loss: 2.3466 - accuracy: 0.0988 - val_loss: 2.3269 - val_accuracy: 0.1141
# Epoch 8/50
# 195/195 [==============================] - 23s 116ms/step - loss: 2.3411 - accuracy: 0.0998 - val_loss: 2.3085 - val_accuracy: 0.1310
# Epoch 9/50
# 195/195 [==============================] - 21s 108ms/step - loss: 2.3351 - accuracy: 0.0982 - val_loss: 2.2907 - val_accuracy: 0.1136
# Epoch 10/50
# 195/195 [==============================] - 22s 113ms/step - loss: 2.3336 - accuracy: 0.1027 - val_loss: 2.2971 - val_accuracy: 0.1433
# Epoch 11/50
# 195/195 [==============================] - 22s 112ms/step - loss: 2.3015 - accuracy: 0.1123 - val_loss: 2.2947 - val_accuracy: 0.1399
# Carregar DataSet: 1.1600 em milissegundos
# Pre-processamento: 1.1900 em milissegundos
# Criação do Modelo: 5.7300 em milissegundos
# Treinamento: 1198.4200 em milissegundos
# Inicio à Fim Execução: 1206.5000 em milissegundos
# 313/313 [==============================] - 2s 6ms/step
# Acuracia:  13.990
# Sensibilidade:  0.140

# %% [markdown]
# ### [CIFAR]Treinamento e ordem de execução das funções
#  * **[Modelo selecionado com entropia]**
#  * **[Baixa entropia]**

# %%
from keras.datasets import cifar10
inicio = time.time() #tempo de inicio
(train_X, train_y), (test_X, test_y) = cifar10.load_data() # Carregar o conjunto de dados # Importar e Treinar
importacaoF = time.time() #tempo de importacao
train_X, train_y = filtrar_entropia_median(train_X, train_y)  #filtro de entropia sob conjunto de dados
entropiaF = time.time() #tempo de filtragem entropia
train_X, train_y, test_X, test_y = carregarPeparar(train_X, train_y, test_X, test_y, 32, 3) #padronização e categorização
datagen = ImageDataGenerator(rotation_range=15,horizontal_flip=True,width_shift_range=0.1,height_shift_range=0.1)
datagen.fit(train_X)
padrozinacaoF = time.time() #tempo de padronizacao
model = criacaoModeloG9() # instanciando o modelo
criacaoModeloF = time.time() #tempo de criacao do modelo
history=model.fit(datagen.flow(train_X, train_y, batch_size=128),
                    steps_per_epoch = len(train_X) / 128, epochs=50, validation_data=(test_X, test_y))
treinamentoF = time.time() #tempo final

tempDecorrido(inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF, entropiaF) #inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF, entropiaF
#plotarDadosTrain(3000, 9, train_X) # Exemplo: apartir do indice N, exibe K imagens do conjunto de dados, D
avaliacao_statistica(test_X, test_y)
plotAcuraciaLoss(history)
# Out:
# Epoch 1/50
# 195/195 [==============================] - 24s 113ms/step - loss: 2.0769 - accuracy: 0.3696 - val_loss: 4.1968 - val_accuracy: 0.1379
# Epoch 2/50
# 195/195 [==============================] - 22s 114ms/step - loss: 1.5158 - accuracy: 0.4795 - val_loss: 1.6079 - val_accuracy: 0.4369
# Epoch 3/50
# 195/195 [==============================] - 21s 108ms/step - loss: 1.2838 - accuracy: 0.5451 - val_loss: 1.1564 - val_accuracy: 0.5883
# Epoch 4/50
# 195/195 [==============================] - 22s 113ms/step - loss: 1.1383 - accuracy: 0.5951 - val_loss: 1.0942 - val_accuracy: 0.6183
# Epoch 5/50
# 195/195 [==============================] - 22s 111ms/step - loss: 1.0572 - accuracy: 0.6236 - val_loss: 1.0996 - val_accuracy: 0.6282
# Epoch 6/50
# 195/195 [==============================] - 22s 111ms/step - loss: 0.9803 - accuracy: 0.6473 - val_loss: 0.9499 - val_accuracy: 0.6782
# Epoch 7/50
# 195/195 [==============================] - 22s 114ms/step - loss: 0.9297 - accuracy: 0.6707 - val_loss: 1.0829 - val_accuracy: 0.6556
# Epoch 8/50
# 195/195 [==============================] - 21s 110ms/step - loss: 0.8807 - accuracy: 0.6885 - val_loss: 1.0997 - val_accuracy: 0.6436
# Epoch 9/50
# 195/195 [==============================] - 21s 109ms/step - loss: 0
50
# 195/195 [==============================] - 22s 113ms/step - loss: 0.4639 - accuracy: 0.8368 - val_loss: 0.5378 - val_accuracy: 0.8249
# Epoch 40/50
# 195/195 [==============================] - 22s 113ms/step - loss: 0.4612 - accuracy: 0.8390 - val_loss: 0.5572 - val_accuracy: 0.8177
# Epoch 41/50
# 195/195 [==============================] - 22s 115ms/step - loss: 0.4564 - accuracy: 0.8430 - val_loss: 0.6180 - val_accuracy: 0.8014
# Epoch 42/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.4441 - accuracy: 0.8440 - val_loss: 0.5250 - val_accuracy: 0.8240
# Epoch 43/50
# 195/195 [==============================] - 22s 111ms/step - loss: 0.4470 - accuracy: 0.8450 - val_loss: 0.5675 - val_accuracy: 0.8147
# Epoch 44/50
# 195/195 [==============================] - 22s 112ms/step - loss: 0.4333 - accuracy: 0.8463 - val_loss: 0.5342 - val_accuracy: 0.8249
# Epoch 45/50
# 195/195 [==============================] - 22s 114ms/step - loss: 0.4296 - accuracy: 0.8516 - val_loss: 0.5573 - val_accuracy: 0.8167
# Epoch 46/50
# 195/195 [==============================] - 22s 111ms/step - loss: 0.4300 - accuracy: 0.8486 - val_loss: 0.5308 - val_accuracy: 0.8272
# Epoch 47/50
# 195/195 [==============================] - 22s 115ms/step - loss: 0.4278 - accuracy: 0.8489 - val_loss: 0.5582 - val_accuracy: 0.8145
# Epoch 48/50
# 195/195 [==============================] - 22s 112ms/step - loss: 0.4256 - accuracy: 0.8474 - val_loss: 0.6498 - val_accuracy: 0.7900
# Epoch 49/50
# 195/195 [==============================] - 24s 121ms/step - loss: 0.4215 - accuracy: 0.8506 - val_loss: 0.5790 - val_accuracy: 0.8166
# Epoch 50/50
# 195/195 [==============================] - 22s 115ms/step - loss: 0.4159 - accuracy: 0.8526 - val_loss: 0.5651 - val_accuracy: 0.8163
# Carregar DataSet: 1.2900 em milissegundos
# Filtro Entropia: 7.4400 em milissegundos
# Pre-processamento: 8.6000 em milissegundos
# Criação do Modelo: 0.2600 em milissegundos
# Treinamento: 1103.1200 em milissegundos
# Inicio à Fim Execução: 1113.2700 em milissegundos
# 313/313 [==============================] - 2s 6ms/step
# Acuracia:  81.630
# Sensibilidade:  0.816

# %% [markdown]
# ### Filtro de entropia :
#   * Dataset filtrado
#   * Median transferida para conjunto de treino

# %%
from keras.datasets import cifar10
inicio = time.time() #tempo de inicio
(train_X, train_y), (test_X, test_y) = cifar10.load_data() # Carregar o conjunto de dados # Importar e Treinar
importacaoF = time.time() #tempo de importacao
train_X, train_y, test_X, test_y = filtrar_entropia_median_train_teste(train_X, train_y, test_X, test_y) #novo filtro da reunião 03-10-2023
entropiaF = time.time() #tempo de filtragem entropia
train_X, train_y, test_X, test_y = carregarPeparar(train_X, train_y, test_X, test_y, 32, 3) #padronização e categorização
datagen = ImageDataGenerator(rotation_range=15,horizontal_flip=True,width_shift_range=0.1,height_shift_range=0.1)
datagen.fit(train_X)
padrozinacaoF = time.time() #tempo de padronizacao
model = criacaoModeloG9() # instanciando o modelo
criacaoModeloF = time.time() #tempo de criacao do modelo
history=model.fit(datagen.flow(train_X, train_y, batch_size=128),
                    steps_per_epoch = len(train_X) / 128, epochs=50, validation_data=(test_X, test_y))
treinamentoF = time.time() #tempo final

tempDecorrido(inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF, entropiaF) #inicio, importacaoF, padrozinacaoF, criacaoModeloF, treinamentoF, entropiaF
#plotarDadosTrain(3000, 9, train_X) # Exemplo: apartir do indice N, exibe K imagens do conjunto de dados, D
50
# 195/195 [==============================] - 21s 106ms/step - loss: 0.4166 - accuracy: 0.8528 - val_loss: 0.5360 - val_accuracy: 0.8239
# Carregar DataSet: 1.0000 em milissegundos
# Filtro Entropia: 7.7900 em milissegundos
# Pre-processamento: 8.7900 em milissegundos
# Criação do Modelo: 2.1300 em milissegundos
# Treinamento: 1046.2900 em milissegundos
# Inicio à Fim Execução: 1058.2200 em milissegundos
# 155/155 [==============================] - 1s 6ms/step
# Acuracia:  82.388
# Sensibilidade:  0.801

# %% [markdown]
# ### Filtro de entropia :
#   * Dataset filtrado
#   * Median transferida para conjunto de treino
#   * Cross-validation

# %%
from sklearn.model_selection import KFold

def crossValidation(combinado_treino_X, combinado_validacao_y,n_folds = 5):
    #divide seus dados em k folds, e treina no k−1 e valida em 1 fold, então a proporção de dados usados para validação é 1/k.
    #2 folds (50% de validação): Treina em 50% dos dados e valida nos outros 50%.
    #5 folds (20% de validação): Treina em 80% dos dados e valida em 20%.
    #10 folds (10% de validação): Treina em 90% dos dados e valida em 10%.    
    n_fold = 5 if n_folds == 0 else n_folds
    datagen = ImageDataGenerator(rotation_range=15,horizontal_flip=True,width_shift_range=0.1,height_shift_range=0.1)
    datagen.fit(combinado_treino_X)
    
    kf = KFold(n_splits = n_folds, shuffle = True, random_state = 42)  #divisão do conjunto de dados
    fold_no = 1
    for train, test in kf.split(combinado_treino_X, combinado_validacao_y):
        print(f"Treinando a rede no folder numero: {fold_no}")
        model = criacaoModeloG9() # instanciando o modelo
        inicio = time.time() #tempo de inicio
        history=model.fit(datagen.flow(combinado_treino_X[train], combinado_validacao_y[train], batch_size=128),
                            steps_per_epoch = len(train_X) / 128, epochs=50, validation_data=(combinado_treino_X[test], combinado_validacao_y[test]))        
           
        treinamentoF = time.time() #tempo final
        tempoTreino = round(treinamentoF - inicio,2)
        scores = model.evaluate(combinado_treino_X[test], combinado_validacao_y[test], verbose = 1)
        print(f"Num do Folder: {fold_no}: Taxa de Loss: {scores[0]}, Taxa de Acuracia: {scores[1]*100:.2f}%, Tamanho do Conjunto de Dados: {len(combinado_treino_X[train])}, Tempo de Treino: {tempoTreino}")
        plt.figure(figsize=(12, 5))
        plt.subplot(1, 2, 1)  # 1 linha, 2 colunas, primeiro gráfico  # Primeiro gráfico (accuracy)
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy']) # Métrica de validação
        plt.title(f'Model Accuracy: {fold_no}')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.subplot(1, 2, 2)  # 1 linha, 2 colunas, segundo gráfico # Segundo gráfico (loss)
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss']) # Métrica de validação
        plt.title(f'Model Loss: {fold_no}')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.tight_layout() # Exibir os gráficos       
        fold_no += 1
        print("\n")
        
#carregar os dados
from keras.datasets import cifar10
(train_X, train_y), (test_X, test_y) = cifar10.load_data() # Carregar o conjunto de dados # Importar e Treinar
train_X, train_y, test_X, test_y = filtrar_entropia_median_train_teste(train_X, train_y, test_X, test_y) #novo filtro da reunião 03-10-2023
train_X, train_y, test_X, test_y = carregarPeparar(train_X, train_y, test_X, test_y, 32, 3) #carregar preparar
combinado_treino_X = np.concatenate([train_X, test_X], axis=0)
combinado_validacao_y = np.concatenate([train_y, test_y], axis=0)

#criar/instanciar o modelo para validação cruzada
crossValidation(combinado_treino_X,combinado_validacao_y, 10)
50
# 195/195 [==============================] - 21s 107ms/step - loss: 0.4415 - accuracy: 0.8446 - val_loss: 0.4271 - val_accuracy: 0.8567
# Epoch 47/50
# 195/195 [==============================] - 20s 103ms/step - loss: 0.4347 - accuracy: 0.8482 - val_loss: 0.4233 - val_accuracy: 0.8507
# Epoch 48/50
# 195/195 [==============================] - 20s 104ms/step - loss: 0.4300 - accuracy: 0.8497 - val_loss: 0.4749 - val_accuracy: 0.8407
# Epoch 49/50
# 195/195 [==============================] - 21s 110ms/step - loss: 0.4323 - accuracy: 0.8484 - val_loss: 0.4300 - val_accuracy: 0.8474
# Epoch 50/50
# 195/195 [==============================] - 20s 104ms/step - loss: 0.4149 - accuracy: 0.8526 - val_loss: 0.4471 - val_accuracy: 0.8517
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4471 - accuracy: 0.8517
# Num do Folder: 1: Taxa de Loss: 0.4470711946487427, Taxa de Acuracia: 85.17%, Tamanho do Conjunto de Dados: 26940, Tempo de Treino: 1089.93
#
#
# Treinando a rede no folder numero: 2
# Epoch 1/50
# 195/195 [==============================] - 24s 113ms/step - loss: 2.0709 - accuracy: 0.3657 - val_loss: 4.7078 - val_accuracy: 0.0698
# Epoch 2/50
# 195/195 [==============================] - 22s 114ms/step - loss: 1.4755 - accuracy: 0.4843 - val_loss: 1.7655 - val_accuracy: 0.4008
# Epoch 3/50
# 195/195 [==============================] - 20s 105ms/step - loss: 1.2538 - accuracy: 0.5555 - val_loss: 1.2327 - val_accuracy: 0.5862
# Epoch 4/50
# 195/195 [==============================] - 22s 110ms/step - loss: 1.1274 - accuracy: 0.5998 - val_loss: 1.1004 - val_accuracy: 0.6420
# Epoch 5/50
# 195/195 [==============================] - 20s 105ms/step - loss: 1.0208 - accuracy: 0.6354 - val_loss: 1.1262 - val_accuracy: 0.6399
# Epoch 6/50
# 195/195 [==============================] - 20s 104ms/step - loss: 0.9793 - accuracy: 0.6521 - val_loss: 0.9234 - val_accuracy: 0.6824
# Epoch 7/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.9196 - accuracy: 0.6721 - val_loss: 1.0110 - val_accuracy: 0.6750
# Epoch 8/50
# 195/195 [==============================] - 21s 107ms/step - loss: 0.8838 - accuracy: 0.6875 - val_loss: 0.9221 - val_accuracy: 0.7041
# Epoch 9/50
# 195/195 [==============================] - 21s 105ms/step - loss: 0.8460 - accuracy: 0.7015 - val_loss: 0.8412 - val_accuracy: 0.7241
# Epoch 10/50
# 195/195 [==============================] - 21s 108ms/step - loss: 0.8136 - accuracy: 0.7123 - val_loss: 0.7753 - val_accuracy: 0.7388
# Epoch 11/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.7826 - accuracy: 0.7268 - val_loss: 0.7943 - val_accuracy: 0.7338
# Epoch 12/50
# 195/195 [==============================] - 21s 106ms/step - loss: 0.7685 - accuracy: 0.7290 - val_loss: 0.7662 - val_accuracy: 0.7505
# Epoch 13/50
# 195/195 [==============================] - 21s 109ms/step - loss: 0.7355 - accuracy: 0.7423 - val_loss: 0.6925 - val_accuracy: 0.7692
# Epoch 14/50
# 195/195 [==============================] - 24s 125ms/step - loss: 0.7286 - accuracy: 0.7463 - val_loss: 0.6801 - val_accuracy: 0.7685
# Epoch 15/50
# 195/195 [==============================] - 25s 126ms/step - loss: 0.7018 - accuracy: 0.7546 - val_loss: 0.7565 - val_accuracy: 0.7535
# Epoch 16/50
# 195/195 [==============================] - 21s 106ms/step - loss: 0.6814 - accuracy: 0.7624 - val_loss: 0.6828 - val_accuracy: 0.7662
# Epoch 17/50
# 195/195 [==============================] - 22s 114ms/step - loss: 0.6696 - accuracy: 0.7662 - val_loss: 0.8167 - val_accuracy: 0.7445
# Epoch 18/50
# 195/195 [==============================] - 22s 113ms/step - loss: 0
50
# 195/195 [==============================] - 22s 112ms/step - loss: 0.9896 - accuracy: 0.6449 - val_loss: 1.0234 - val_accuracy: 0.6602
# Epoch 7/50
# 195/195 [==============================] - 22s 114ms/step - loss: 0.9376 - accuracy: 0.6682 - val_loss: 0.9534 - val_accuracy: 0.6742
# Epoch 8/50
# 195/195 [==============================] - 21s 110ms/step - loss: 0.8906 - accuracy: 0.6858 - val_loss: 0.8733 - val_accuracy: 0.6919
# Epoch 9/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.8638 - accuracy: 0.6929 - val_loss: 0.8875 - val_accuracy: 0.7036
# Epoch 10/50
# 195/195 [==============================] - 21s 110ms/step - loss: 0.8355 - accuracy: 0.7032 - val_loss: 0.8293 - val_accuracy: 0.7100
# Epoch 11/50
# 195/195 [==============================] - 21s 109ms/step - loss: 0.7990 - accuracy: 0.7165 - val_loss: 0.8254 - val_accuracy: 0.7180
# Epoch 12/50
# 195/195 [==============================] - 23s 117ms/step - loss: 0.7758 - accuracy: 0.7274 - val_loss: 0.8763 - val_accuracy: 0.7056
# Epoch 13/50
# 195/195 [==============================] - 21s 109ms/step - loss: 0.7590 - accuracy: 0.7343 - val_loss: 0.8545 - val_accuracy: 0.7244
# Epoch 14/50
# 195/195 [==============================] - 22s 112ms/step - loss: 0.7268 - accuracy: 0.7449 - val_loss: 1.0788 - val_accuracy: 0.6656
# Epoch 15/50
# 195/195 [==============================] - 22s 109ms/step - loss: 0.7098 - accuracy: 0.7513 - val_loss: 0.6679 - val_accuracy: 0.7678
# Epoch 16/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.6878 - accuracy: 0.7572 - val_loss: 0.7959 - val_accuracy: 0.7451
# Epoch 17/50
# 195/195 [==============================] - 22s 114ms/step - loss: 0.6821 - accuracy: 0.7610 - val_loss: 0.7250 - val_accuracy: 0.7631
# Epoch 18/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.6680 - accuracy: 0.7666 - val_loss: 0.6041 - val_accuracy: 0.7928
# Epoch 19/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.6488 - accuracy: 0.7742 - val_loss: 0.6188 - val_accuracy: 0.7852
# Epoch 20/50
# 195/195 [==============================] - 21s 109ms/step - loss: 0.6334 - accuracy: 0.7780 - val_loss: 0.6347 - val_accuracy: 0.7822
# Epoch 21/50
# 195/195 [==============================] - 22s 113ms/step - loss: 0.6226 - accuracy: 0.7808 - val_loss: 0.5886 - val_accuracy: 0.7972
# Epoch 22/50
# 195/195 [==============================] - 22s 114ms/step - loss: 0.6023 - accuracy: 0.7889 - val_loss: 0.7218 - val_accuracy: 0.7701
# Epoch 23/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.5974 - accuracy: 0.7874 - val_loss: 0.5254 - val_accuracy: 0.8219
# Epoch 24/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.5791 - accuracy: 0.7982 - val_loss: 0.6180 - val_accuracy: 0.7915
# Epoch 25/50
# 195/195 [==============================] - 22s 111ms/step - loss: 0.5719 - accuracy: 0.8006 - val_loss: 0.5892 - val_accuracy: 0.8059
# Epoch 26/50
# 195/195 [==============================] - 21s 109ms/step - loss: 0.5577 - accuracy: 0.8054 - val_loss: 0.5811 - val_accuracy: 0.8015
# Epoch 27/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.5576 - accuracy: 0.8029 - val_loss: 0.5395 - val_accuracy: 0.8169
# Epoch 28/50
# 195/195 [==============================] - 21s 110ms/step - loss: 0.5522 - accuracy: 0.8089 - val_loss: 0.5238 - val_accuracy: 0.8223
# Epoch 29/50
# 195/195 [==============================] - 22s 112ms/step - loss: 0.5408 - accuracy: 0.8124 - val_loss: 0.5640 - val_accuracy: 0.8192
# Epoch 30/50
# 195/195 [==============================] - 22s 113ms/step - loss: 0.5314 - accuracy: 0.8159 - val_loss: 0.6168 - val_accuracy: 0.8069
# Epoch 31/50
# 195/195 [==============================] - 21s 109ms/step - loss: 0.5183 - accuracy: 0.8206 - val_loss: 0.5655 - val_accuracy: 0.8152
# Epoch 32/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.5156 - accuracy: 0.8212 - val_loss: 0.5053 - val_accuracy: 0.8326
# Epoch 33/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0
50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.9756 - accuracy: 0.6531 - val_loss: 0.8204 - val_accuracy: 0.7127
# Epoch 7/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.9296 - accuracy: 0.6703 - val_loss: 0.8724 - val_accuracy: 0.7033
# Epoch 8/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.8923 - accuracy: 0.6851 - val_loss: 0.8160 - val_accuracy: 0.7133
# Epoch 9/50
# 195/195 [==============================] - 22s 113ms/step - loss: 0.8560 - accuracy: 0.6979 - val_loss: 0.7573 - val_accuracy: 0.7324
# Epoch 10/50
# 195/195 [==============================] - 21s 110ms/step - loss: 0.8124 - accuracy: 0.7114 - val_loss: 0.7755 - val_accuracy: 0.7290
# Epoch 11/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.7927 - accuracy: 0.7184 - val_loss: 0.7822 - val_accuracy: 0.7384
# Epoch 12/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.7593 - accuracy: 0.7323 - val_loss: 0.7692 - val_accuracy: 0.7364
# Epoch 13/50
# 195/195 [==============================] - 21s 109ms/step - loss: 0.7429 - accuracy: 0.7409 - val_loss: 0.7392 - val_accuracy: 0.7444
# Epoch 14/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.7201 - accuracy: 0.7494 - val_loss: 0.8280 - val_accuracy: 0.7384
# Epoch 15/50
# 195/195 [==============================] - 21s 109ms/step - loss: 0.7008 - accuracy: 0.7539 - val_loss: 0.7387 - val_accuracy: 0.7467
# Epoch 16/50
# 195/195 [==============================] - 22s 112ms/step - loss: 0.6766 - accuracy: 0.7626 - val_loss: 0.7341 - val_accuracy: 0.7441
# Epoch 17/50
# 195/195 [==============================] - 22s 115ms/step - loss: 0.6643 - accuracy: 0.7684 - val_loss: 0.7406 - val_accuracy: 0.7574
# Epoch 18/50
# ...
# Epoch 47/50
# 195/195 [==============================] - 22s 112ms/step - loss: 0.4410 - accuracy: 0.8464 - val_loss: 0.4807 - val_accuracy: 0.8400
# Epoch 48/50
# 195/195 [==============================] - 21s 108ms/step - loss: 0.4391 - accuracy: 0.8463 - val_loss: 0.5918 - val_accuracy: 0.8102
# Epoch 49/50
# 195/195 [==============================] - 22s 113ms/step - loss: 0.4314 - accuracy: 0.8505 - val_loss: 0.4901 - val_accuracy: 0.8353
# Epoch 50/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.4278 - accuracy: 0.8481 - val_loss: 0.4455 - val_accuracy: 0.8507
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4455 - accuracy: 0.8507
# Num do Folder: 8: Taxa de Loss: 0.44547781348228455, Taxa de Acuracia: 85.07%, Tamanho do Conjunto de Dados: 26941, Tempo de Treino: 1171.36
#
#
# Treinando a rede no folder numero: 9
# Epoch 1/50
# 195/195 [==============================] - 25s 122ms/step - loss: 2.0711 - accuracy: 0.3690 - val_loss: 3.7893 - val_accuracy: 0.1834
# Epoch 2/50
# 195/195 [==============================] - 21s 109ms/step - loss: 1.4696 - accuracy: 0.4927 - val_loss: 1.5819 - val_accuracy: 0.4661
# Epoch 3/50
# 195/195 [==============================] - 21s 109ms/step - loss: 1.2433 - accuracy: 0.5602 - val_loss: 1.4520 - val_accuracy: 0.5393
# Epoch 4/50
# 195/195 [==============================] - 23s 117ms/step - loss: 1.1142 - accuracy: 0.6020 - val_loss: 1.1057 - val_accuracy: 0.6318
# Epoch 5/50
# 195/195 [==============================] - 21s 108ms/step - loss: 1.0262 - accuracy: 0.6349 - val_loss: 1.4076 - val_accuracy: 0.6074
# Epoch 6/50
# 195/195 [==============================] - 22s 111ms/step - loss: 0.9656 - accuracy: 0.6591 - val_loss: 0.9734 - val_accuracy: 0.6726
# Epoch 7/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.9150 - accuracy: 0.6751 - val_loss: 1.0946 - val_accuracy: 0.6622
# Epoch 8/50
# 195/195 [==============================] - 22s 112ms/step - loss: 0.8806 - accuracy: 0.6915 - val_loss: 1.0618 - val_accuracy: 0.6709
# Epoch 9/50
# 195/195 [==============================] - 22s 113ms/step - loss: 0.8340 - accuracy: 0.7066 - val_loss: 0.7768 - val_accuracy: 0.7287
# Epoch 10/50
# 195/195 [==============================] - 21s 108ms/step - loss: 0.8191 - accuracy: 0.7123 - val_loss: 0.8423 - val_accuracy: 0.7257
# Epoch 11/50
# 195/195 [==============================] - 24s 123ms/step - loss: 0.7883 - accuracy: 0.7225 - val_loss: 0.7250 - val_accuracy: 0.7504
# Epoch 12/50
# 195/195 [==============================] - 34s 175ms/step - loss: 0.7585 - accuracy: 0.7311 - val_loss: 0.7285 - val_accuracy: 0.7541
# Epoch 13/50
# 195/195 [==============================] - 28s 141ms/step - loss: 0.7403 - accuracy: 0.7387 - val_loss: 0.6842 - val_accuracy: 0.7701
# Epoch 14/50
# 195/195 [==============================] - 27s 137ms/step - loss: 0.7089 - accuracy: 0.7530 - val_loss: 0.9946 - val_accuracy: 0.7070
# Epoch 15/50
# 195/195 [==============================] - 23s 119ms/step - loss: 0.7008 - accuracy: 0.7567 - val_loss: 0.7546 - val_accuracy: 0.7467
# Epoch 16/50
# 195/195 [==============================] - 22s 115ms/step - loss: 0.6822 - accuracy: 0.7591 - val_loss: 0.6382 - val_accuracy: 0.7908
# Epoch 17/50
# 195/195 [==============================] - 21s 109ms/step - loss: 0.6732 - accuracy: 0.7636 - val_loss: 0.7222 - val_accuracy: 0.7725
# Epoch 18/50
# 195/195 [==============================] - 22s 115ms/step - loss: 0.6563 - accuracy: 0.7718 - val_loss: 0.7998 - val_accuracy: 0.7437
# Epoch 19/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.6414 - accuracy: 0.7789 - val_loss: 0.6172 - val_accuracy: 0.7969
# Epoch 20/50
# 195/195 [==============================] - 22s 113ms/step - loss: 0.6348 - accuracy: 0.7779 - val_loss: 0.6707 - val_accuracy: 0.7778
# Epoch 21/50
# 195/195 [==============================] - 22s 109ms/step - loss: 0.6083 - accuracy: 0.7865 - val_loss: 0.5999 - val_accuracy: 0.8032
# Epoch 22/50
# 195/195 [==============================] - 23s 115ms/step - loss: 0.5998 - accuracy: 0.7924 - val_loss: 0.5656 - val_accuracy: 0.8082
# Epoch 23/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.6004 - accuracy: 0.7884 - val_loss: 0.6294 - val_accuracy: 0.7972
# Epoch 24/50
# 195/195 [==============================] - 22s 112ms/step - loss: 0.5825 - accuracy: 0.7975 - val_loss: 0.5396 - val_accuracy: 0.8136
# Epoch 25/50
# 195/195 [==============================] - 22s 115ms/step - loss: 0.5704 - accuracy: 0.8024 - val_loss: 0.5857 - val_accuracy: 0.8086
# Epoch 26/50
# 195/195 [==============================] - 21s 109ms/step - loss: 0.5632 - accuracy: 0.8049 - val_loss: 0.5380 - val_accuracy: 0.8172
# Epoch 27/50
# 195/195 [==============================] - 22s 114ms/step - loss: 0.5509 - accuracy: 0.8099 - val_loss: 0.6649 - val_accuracy: 0.7878
# Epoch 28/50
# 195/195 [==============================] - 22s 113ms/step - loss: 0.5417 - accuracy: 0.8117 - val_loss: 0.5501 - val_accuracy: 0.8172
# Epoch 29/50
# 195/195 [==============================] - 21s 110ms/step - loss: 0.5470 - accuracy: 0.8113 - val_loss: 0.5178 - val_accuracy: 0.8249
# Epoch 30/50
# 195/195 [==============================] - 23s 117ms/step - loss: 0.5350 - accuracy: 0.8129 - val_loss: 0.4858 - val_accuracy: 0.8353
# Epoch 31/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.5283 - accuracy: 0.8155 - val_loss: 0.5486 - val_accuracy: 0.8206
# Epoch 32/50
# 195/195 [==============================] - 22s 111ms/step - loss: 0
# 195/195 [==============================] - 24s 117ms/step - loss: 1.2508 - accuracy: 0.5550 - val_loss: 1.0854 - val_accuracy: 0.6201
# Epoch 4/50
# 195/195 [==============================] - 22s 111ms/step - loss: 1.1360 - accuracy: 0.5984 - val_loss: 1.1760 - val_accuracy: 0.6241
# Epoch 5/50
# 195/195 [==============================] - 22s 112ms/step - loss: 1.0423 - accuracy: 0.6322 - val_loss: 0.9931 - val_accuracy: 0.6652
# Epoch 6/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.9803 - accuracy: 0.6520 - val_loss: 1.2323 - val_accuracy: 0.6138
# Epoch 7/50
# 195/195 [==============================] - 22s 111ms/step - loss: 0.9342 - accuracy: 0.6704 - val_loss: 0.9461 - val_accuracy: 0.6970
# Epoch 8/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.8807 - accuracy: 0.6881 - val_loss: 0.8491 - val_accuracy: 0.7203
# Epoch 9/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.8510 - accuracy: 0.6996 - val_loss: 0.7542 - val_accuracy: 0.7340
# Epoch 10/50
# 195/195 [==============================] - 22s 111ms/step - loss: 0.8179 - accuracy: 0.7086 - val_loss: 0.8475 - val_accuracy: 0.7140
# Epoch 11/50
# 195/195 [==============================] - 23s 115ms/step - loss: 0.7950 - accuracy: 0.7212 - val_loss: 0.7149 - val_accuracy: 0.7491
# Epoch 12/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.7640 - accuracy: 0.7316 - val_loss: 0.9164 - val_accuracy: 0.7053
# Epoch 13/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.7400 - accuracy: 0.7391 - val_loss: 0.6816 - val_accuracy: 0.7681
# Epoch 14/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.7225 - accuracy: 0.7459 - val_loss: 0.6994 - val_accuracy: 0.7541
# Epoch 15/50
# 195/195 [==============================] - 23s 115ms/step - loss: 0.7070 - accuracy: 0.7536 - val_loss: 0.7854 - val_accuracy: 0.7384
# Epoch 16/50
# 195/195 [==============================] - 22s 113ms/step - loss: 0.6885 - accuracy: 0.7559 - val_loss: 0.7294 - val_accuracy: 0.7578
# Epoch 17/50
# 195/195 [==============================] - 22s 113ms/step - loss: 0.6703 - accuracy: 0.7652 - val_loss: 0.7126 - val_accuracy: 0.7685
# Epoch 18/50
# 195/195 [==============================] - 23s 117ms/step - loss: 0.6617 - accuracy: 0.7686 - val_loss: 0.6884 - val_accuracy: 0.7835
# Epoch 19/50
# 195/195 [==============================] - 22s 111ms/step - loss: 0.6425 - accuracy: 0.7761 - val_loss: 0.5877 - val_accuracy: 0.8055
# Epoch 20/50
# 195/195 [==============================] - 22s 113ms/step - loss: 0.6318 - accuracy: 0.7801 - val_loss: 0.6382 - val_accuracy: 0.7905
# Epoch 21/50
# 195/195 [==============================] - 23s 115ms/step - loss: 0.6196 - accuracy: 0.7835 - val_loss: 0.6417 - val_accuracy: 0.7888
# Epoch 22/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.6084 - accuracy: 0.7864 - val_loss: 0.6869 - val_accuracy: 0.7815
# Epoch 23/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.5975 - accuracy: 0.7924 - val_loss: 0.7097 - val_accuracy: 0.7745
# Epoch 24/50
# 195/195 [==============================] - 22s 111ms/step - loss: 0.5890 - accuracy: 0.7940 - val_loss: 0.6717 - val_accuracy: 0.7795
# Epoch 25/50
# 195/195 [==============================] - 22s 112ms/step - loss: 0.5773 - accuracy: 0.7990 - val_loss: 0.6631 - val_accuracy: 0.7902
# Epoch 26/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.5651 - accuracy: 0.8022 - val_loss: 0.5210 - val_accuracy: 0.8296
# Epoch 27/50
# 195/195 [==============================] - 22s 110ms/step - loss: 0.5600 - accuracy: 0.8027 - val_loss: 0.5318 - val_accuracy: 0.8223
# Epoch 28/50
# 195/195 [==============================] - 23s 116ms/step - loss: 0.5537 - accuracy: 0.8080 - val_loss: 0.7474 - val_accuracy: 0.7681
# Epoch 29/50
# 195/195 [==============================] - 22s 113ms/step - loss: 0